# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\LENOVO\Downloads\world_population_excel_workbook.xlsx")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
#Filtering
df[df['Rank'] > 20 ]
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
specific_countries = ['Zambia','Yemen']

df[df['Country'].isin(specific_countries)]
# Out:
#      Rank CCA3 Country Capital Continent  2022 Population  2020 Population  \
# 231    46  YEM   Yemen   Sanaa      Asia         33696614         32284046
# 232    63  ZMB  Zambia  Lusaka    Africa         20017675         18927715
#
#      2015 Population  2010 Population  2000 Population  1990 Population  \
# 231         28516545         24743946         18628700         13375121
# 232         16248230         13792086          9891136          7686401
#
#      1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# 231          9204938          6843607       527968             63.8232
# 232          5720438          4281671       752612             26.5976
#
#      Growth Rate  World Population Percentage
# 231       1.0217                         0.42
# 232       1.0280                         0.25

# %%
#contains

df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219          9441129          9287289          8916899          8481771
# 220         67508936         67059474         65224364         62760039
# 221        338289857        335942003        324607776        311182845
# 222            99465           100442           102803           106142
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219          3275333          1900151          1014048           298084
# ...

# %%
df2 = df.set_index('Country')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.filter(items = ['Capital','Rank'])
# Out:
#                             Capital  Rank
# Country
# Afghanistan                   Kabul    36
# Albania                      Tirana   138
# Algeria                     Algiers    34
# American Samoa            Pago Pago   213
# Andorra            Andorra la Vella   203
# ...                             ...   ...
# Wallis and Futuna          Mata-Utu   226
# Western Sahara            El AaiÃºn   172
# Yemen                         Sanaa    46
# Zambia                       Lusaka    63
# Zimbabwe                     Harare    74
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Continent','2022 Population'])
# Out:
#                   Continent  2022 Population
# Country
# Afghanistan            Asia         41128771
# Albania              Europe          2842321
# Algeria              Africa         44903225
# American Samoa      Oceania            44273
# Andorra              Europe            79824
# ...                     ...              ...
# Wallis and Futuna   Oceania            11572
# Western Sahara       Africa           575986
# Yemen                  Asia         33696614
# Zambia               Africa         20017675
# Zimbabwe             Africa         16320537
#
# [234 rows x 2 columns]

# %%
df2.filter(items = ['Algeria'], axis = 0)
# Out:
#          Rank CCA3  Capital Continent  2022 Population  2020 Population  \
# Algeria    34  DZA  Algiers    Africa         44903225         43451666
#
#          2015 Population  2010 Population  2000 Population  1990 Population  \
# Algeria         39543154         35856344         30774621         25518074
#
#          1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# Algeria         18739378         13795915      2381741             18.8531
#
#          Growth Rate  World Population Percentage
# Algeria       1.0164                         0.56

# %%
df2.filter(items = ['Yemen'], axis = 0)
# Out:
#        Rank CCA3 Capital Continent  2022 Population  2020 Population  \
# Yemen    46  YEM   Sanaa      Asia         33696614         32284046
#
#        2015 Population  2010 Population  2000 Population  1990 Population  \
# Yemen         28516545         24743946         18628700         13375121
#
#        1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# Yemen          9204938          6843607       527968             63.8232
#
#        Growth Rate  World Population Percentage
# Yemen       1.0217                         0.42

# %%
df2.filter(like = 'United' , axis = 0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country
# United Arab Emirates            97  ARE         Abu Dhabi           Asia
# United Kingdom                  21  GBR            London         Europe
# United States                    3  USA  Washington, D.C.  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country
# United Arab Emirates                  9441129          9287289
# United Kingdom                       67508936         67059474
# United States                       338289857        335942003
# United States Virgin Islands            99465           100442
#
#                               2015 Population  2010 Population  \
# Country
# United Arab Emirates                  8916899          8481771
# United Kingdom                       65224364         62760039
# ...

# %%
df2.filter(like = 'Western', axis = 0)
# Out:
#                 Rank CCA3    Capital Continent  2022 Population  \
# Country
# Western Sahara   172  ESH  El AaiÃºn    Africa           575986
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Western Sahara           556048           491824           413296
#
#                 2000 Population  1990 Population  1980 Population  \
# Country
# Western Sahara           270375           178529           116775
#
#                 1970 Population  Area (kmÂ²)  Density (per kmÂ²)  Growth Rate  \
# Country
# Western Sahara            76371       266000              2.1654       1.0184
#
#                 World Population Percentage
# Country
# Western Sahara                         0.01

# %%
df2.filter(items = ['Continent'], axis = 1)
# Out:
#                   Continent
# Country
# Afghanistan            Asia
# Albania              Europe
# Algeria              Africa
# American Samoa      Oceania
# Andorra              Europe
# ...                     ...
# Wallis and Futuna   Oceania
# Western Sahara       Africa
# Yemen                  Asia
# Zambia               Africa
# Zimbabwe             Africa
#
# [234 rows x 1 columns]

# %%
df2.filter(items = ["India"], axis = 0)
# Out:
#        Rank CCA3    Capital Continent  2022 Population  2020 Population  \
# India     2  IND  New Delhi      Asia       1417173173       1396387127
#
#        2015 Population  2010 Population  2000 Population  1990 Population  \
# India       1322866505       1240613620       1059633675        870452165
#
#        1980 Population  1970 Population  Area (kmÂ²)  Density (per kmÂ²)  \
# India        696828385        557501301      3287590            431.0675
#
#        Growth Rate  World Population Percentage
# India       1.0068                        17.77

# %%
df2.loc["Andorra"]
# Out:
# Rank                                        203
# CCA3                                        AND
# Capital                        Andorra la Vella
# Continent                                Europe
# 2022 Population                           79824
# 2020 Population                           77700
# 2015 Population                           71746
# 2010 Population                           71519
# 2000 Population                           66097
# 1990 Population                           53569
# 1980 Population                           35611
# 1970 Population                           19860
# Area (kmÂ²)                                 468
# Density (per kmÂ²)                     170.5641
# Growth Rate                                1.01
# World Population Percentage                 0.0
# Name: Andorra, dtype: object

# %%
df2.loc["United States Virgin Islands"]
# Out:
# Rank                                        200
# CCA3                                        VIR
# Capital                        Charlotte Amalie
# Continent                         North America
# 2022 Population                           99465
# 2020 Population                          100442
# 2015 Population                          102803
# 2010 Population                          106142
# 2000 Population                          108185
# 1990 Population                          100685
# 1980 Population                           96640
# 1970 Population                           63446
# Area (kmÂ²)                                 347
# Density (per kmÂ²)                     286.6427
# Growth Rate                              0.9937
# World Population Percentage                 0.0
# Name: United States Virgin Islands, dtype: object

# %%
df2.iloc[56]
# Out:
# Rank                                      67
# CCA3                                     ECU
# Capital                                Quito
# Continent                      South America
# 2022 Population                     18001000
# 2020 Population                     17588595
# 2015 Population                     16195902
# 2010 Population                     14989585
# 2000 Population                     12626507
# 1990 Population                     10449837
# 1980 Population                      8135845
# 1970 Population                      6172215
# Area (kmÂ²)                           276841
# Density (per kmÂ²)                   65.0229
# Growth Rate                           1.0114
# World Population Percentage             0.23
# Name: Ecuador, dtype: object

# %%
#Order By

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df[df['Rank'] < 10 ].sort_values(by = ['Rank'],ascending =  True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 171     9  RUS         Russia            Moscow         Europe
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 41      1  CHN          China           Beijing           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 171        144713314        145617329        144668389        143242599
# 16         171186372        167420951        157830000        148391139
# 27         215313498        213196304        205188205        196353492
# ...

# %%
df[df["Country"].str.contains("United", case =False, na =False)].sort_values(by="Rank")
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 221     3  USA                 United States  Washington, D.C.  North America
# 220    21  GBR                United Kingdom            London         Europe
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 221        338289857        335942003        324607776        311182845
# 220         67508936         67059474         65224364         62760039
# 219          9441129          9287289          8916899          8481771
# 222            99465           100442           102803           106142
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 221        282398554        248083732        223140018        200328340
# ...

# %%
df[df["Rank"] <= 10 ].sort_values(by=['Capital','World Population Percentage'],ascending = False)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 221     3  USA  United States  Washington, D.C.  North America
# 92      2  IND          India         New Delhi           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 221        338289857        335942003        324607776        311182845
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
df.sort_values(by='CCA3', ascending=True)
# Out:
#      Rank CCA3       Country     Capital      Continent  2022 Population  \
# 10    198  ABW         Aruba  Oranjestad  North America           106445
# 0      36  AFG   Afghanistan       Kabul           Asia         41128771
# 5      42  AGO        Angola      Luanda         Africa         35588987
# 6     224  AIA      Anguilla  The Valley  North America            15857
# 1     138  ALB       Albania      Tirana         Europe          2842321
# ..    ...  ...           ...         ...            ...              ...
# 179   188  WSM         Samoa        Apia        Oceania           222382
# 231    46  YEM         Yemen       Sanaa           Asia         33696614
# 193    24  ZAF  South Africa    Pretoria         Africa         59893885
# 232    63  ZMB        Zambia      Lusaka         Africa         20017675
# 233    74  ZWE      Zimbabwe      Harare         Africa         16320537
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...
